# %%
import pandas as pd

# %%
df = pd.read_excel('Real estate valuation data set.xlsx')
df
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1          2012.916667          32.0
# 1      2          2012.916667          19.5
# 2      3          2013.583333          13.3
# 3      4          2013.500000          13.3
# 4      5          2012.833333           5.0
# ..   ...                  ...           ...
# 409  410          2013.000000          13.7
# 410  411          2012.666667           5.6
# 411  412          2013.250000          18.8
# 412  413          2013.000000           8.1
# 413  414          2013.500000           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
df = df.rename(columns={"X5 latitude": "latitude", "X6 longitude": "longitude", "X2 house age": "house age", "X1 transaction date": "transaction date",
                        "X3 distance to the nearest MRT station": "distance MRT station", "X4 number of convenience stores": "number of convenience stores", "Y house price of unit area": "price"})
df
# Out:
#       No  transaction date  house age  distance MRT station  \
# 0      1       2012.916667       32.0              84.87882
# 1      2       2012.916667       19.5             306.59470
# 2      3       2013.583333       13.3             561.98450
# 3      4       2013.500000       13.3             561.98450
# 4      5       2012.833333        5.0             390.56840
# ..   ...               ...        ...                   ...
# 409  410       2013.000000       13.7            4082.01500
# 410  411       2012.666667        5.6              90.45606
# 411  412       2013.250000       18.8             390.96960
# 412  413       2013.000000        8.1             104.81010
# 413  414       2013.500000        6.5              90.45606
#
#      number of convenience stores  latitude  longitude  price
# 0                              10  24.98298  121.54024   37.9
# 1                               9  24.98034  121.53951   42.2
# ...

# %%
# Percorso del file Excel


# Carica il file Excel nel DataFrame
df = pd.read_excel('Real estate valuation data set.xlsx')

# Visualizza le prime righe per essere sicuro che i dati siano caricati correttamente
print(df.head())
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1          2012.916667          32.0
# 1   2          2012.916667          19.5
# 2   3          2013.583333          13.3
# 3   4          2013.500000          13.3
# 4   5          2012.833333           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %%
import sqlite3
from src import config

# Crea una connessione al database SQLite
conn = sqlite3.connect(config.DATABASE_PATH)

# Verifica che la connessione sia stata stabilita correttamente
print("Connessione al database riuscita")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 2
#       1 import sqlite3
# ----> 2 from src import config
#       4 # Crea una connessione al database SQLite
#       5 conn = sqlite3.connect(config.DATABASE_PATH)
#
# ModuleNotFoundError: No module named 'src'
